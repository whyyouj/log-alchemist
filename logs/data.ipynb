# %%
import pandas as pd

df_cc = pd.read_csv("Credit card transactions - India - Simple.csv")
df_cc
# Out:
#        index                   City       Date  Card Type Exp Type Gender  \
# 0          0           Delhi, India  29-Oct-14       Gold    Bills      F
# 1          1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F
# 2          2       Bengaluru, India  27-Aug-14     Silver    Bills      F
# 3          3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F
# 4          4       Bengaluru, India   5-May-15       Gold    Bills      F
# ...      ...                    ...        ...        ...      ...    ...
# 26047  26047         Kolkata, India  22-Jun-14     Silver   Travel      F
# 26048  26048            Pune, India   3-Aug-14  Signature   Travel      M
# 26049  26049       Hyderabad, India  16-Jan-15     Silver   Travel      M
# 26050  26050          Kanpur, India  14-Sep-14     Silver   Travel      M
# 26051  26051       Hyderabad, India  19-Oct-13  Signature    Bills      M
#
#        Amount
# 0       82475
# 1       32555
# 2      101738
# 3      123424
# ...

# %%
import plotly.express as px
card_type_counts = df_cc["Card Type"].value_counts()

# Convert the Series to a DataFrame for easier plotting
card_type_counts_df = card_type_counts.reset_index()
card_type_counts_df.columns = ['Card Type', 'Count']

# Create a bar chart with Plotly
fig = px.bar(card_type_counts_df, x='Card Type', y='Count', title='Card Type Distribution', 
             labels={'Card Type': 'Card Type', 'Count': 'Number of Cards'})

# Show the figure
fig.write_image("card_type_distribution.png")

# %%
df_a
# Out:
#                                               AuditData          CreationDate  \
# 0     {"CreationTime":"2021-05-18T21:13:33","Id":"f1...  5/18/2021 9:13:33 PM
# 1     {"CreationTime":"2021-05-18T21:13:34","Id":"1e...  5/18/2021 9:13:34 PM
# 2     {"CreationTime":"2021-05-18T21:13:35","Id":"b7...  5/18/2021 9:13:35 PM
# 3     {"CreationTime":"2021-05-18T21:13:35","Id":"a5...  5/18/2021 9:13:35 PM
# 4     {"CreationTime":"2021-05-18T21:13:35","Id":"d1...  5/18/2021 9:13:35 PM
# ...                                                 ...                   ...
# 9606  {"CreationTime":"2021-04-16T07:23:16","Id":"12...  4/16/2021 7:23:16 AM
# 9607  {"CreationTime":"2021-04-16T07:23:21","Id":"3e...  4/16/2021 7:23:21 AM
# 9608  {"CreationTime":"2021-04-16T07:24:14","Id":"12...  4/16/2021 7:24:14 AM
# 9609  {"CreationTime":"2021-04-16T07:25:40","Id":"7d...  4/16/2021 7:25:40 AM
# 9610  {"CreationTime":"2021-04-19T08:45:34","Id":"19...  4/19/2021 8:45:34 AM
#
# ...

# %%
pd.set_option("display.max_columns", None)
df_a = pd.read_csv("auditrecords.csv")

card_type_counts = df_a["Operations"].value_counts()

# Convert the Series to a DataFrame for easier plotting
card_type_counts_df = card_type_counts.reset_index()
card_type_counts_df.columns = ['Operations', 'Count']

# Create a bar chart with Plotly
fig = px.bar(card_type_counts_df, x='Operations', y='Count', title='Card Type Distribution', 
             labels={'Card Type': 'Operations', 'Count': 'Number of Operations'})

# Show the figure
fig.update_layout(xaxis_tickangle=-45)
fig.write_image("Operations.png")
